# %% [markdown]
# <a href="https://colab.research.google.com/github/neljosephrellanos-bit/cs1-python-Emerald-Rellanos/blob/main/GITHUB_COLAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input ("Enter your name")
print ("Hello", name)
# Out:
# Enter your namecasey
# Hello casey

# %%
num1 = int(input ("Enter first number: "))
num2 = int(input ("Enter second number: "))
print(num1 + num2)
# Out:
# Enter first number: 200
# Enter second number: 91
# 291

# %%
num1 = int(input ("Enter first number: "))
num2 = int(input ("Enter second number: "))
num3 = int(input ("Enter third number: "))

if num1 >= num2 and num1 >= num3:
  print(num1, "is the greatest number")
elif num2 >= num1 and num2 >= num3:
  print(num2, "is the greatest number")
else:
  print(num3, "is the greatest number")
# Out:
# Enter first number: 22
# Enter second number: 23
# Enter third number: 23
# 23 is the greatest number
